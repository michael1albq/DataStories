# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
from rake_nltk import Rake
import pandas as pd
import requests
from IPython.display import Image, display
from timeit import default_timer as timer
import pprint
import sys
from timeit import default_timer as timer
import gensim
import string

# %%
# Utilities
def print_song_keywords(Song_Name):
    rake = Rake()
    rake.extract_keywords_from_text(get_song(Song_Name))
    for i in range(0,len(rake.get_ranked_phrases_with_scores())):
        print(str(rake.get_ranked_phrases_with_scores()[i]))

def extract_song_keywords(Song_Name):
    rake = Rake()
    return rake.extract_keywords_from_text(get_song(Song_Name))

def get_song(title):
    return Songs.loc[title]["text"]

def print_song(title):
    print(get_song(title))
    
def createDict(keywords,N):
    Dict = {}
    r = requests.get('https://pixabay.com/api/?key=6713313-c85a6d8e3f6fe1a13b85f7d78&q='+"+".join(keywords)+'&image_type=photo&page=1&per_page='+str(N))
    for img in r.json()['hits']:
        Dict[img['webformatURL']] = img["tags"].split(",")
    return Dict

def displayDict(Dict,limit):
    i = 1
    urls = Dict.keys()
    
    for url in urls:
        print(url)
        print(Dict[url])
        display(Image(url,height=700,width=1000,embed=True))
        print("\n")
        if(i == limit): 
            break
        i += 1

# %%
breaker = "\n \n"
# Pre-processing
Songs = pd.read_csv("songdata.csv")
Songs.set_index("song",inplace=True)
Songs.drop(["artist","link"],inplace=True,axis=1)

# %%
rake = Rake()
rake.extract_keywords_from_text('Almost heaven, West Virginia,  Blue ridge mountain, Shenandoah river,  Life is old there, older than the trees,  Younger than the mountains, growing like a breeze ')
#rake.get_ranked_phrases_with_scores()

# %%
# Song Name -> List of URLS

Max_number_of_search_results = 200

start    = timer()
keywords = ['radio']
Dict     = createDict(keywords, Max_number_of_search_results)

print("\nTime taken:           " +  str(timer() - start) + "\nSize of Table Element:         " + str(len(Dict.keys())))
# Out:
# Time taken:           0.832467533999079
# Size of Table Element:         200

# %%
start = timer()
model = gensim.models.KeyedVectors.load_word2vec_format('~/Projects/DataSources/GoogleNews-vectors-negative300.bin',binary=True)
print(str(timer() - start))
# Out:
# 45.3722310739995

# %%
nlp = model.wv

# %%
tags = list(Dict.values())[4]

tags
# Out:
# ['boy', ' radio', ' retro']

# %%
# vector of similiar words to each tag
for tag in tags:
    # just a way to convert keywords into a form that can be submitted to a query
    filteredform = "".join((char for char in tag.lower().strip() if char not in string.punctuation))
    print(tag + "-> " + str(model.wv.most_similar(filteredform,topn=10)))
    print("\n")
# Out:
# boy-> [('girl', 0.8543272018432617), ('teenager', 0.7606689929962158), ('toddler', 0.7043969631195068), ('teenage_girl', 0.6851483583450317), ('man', 0.6824870705604553), ('teen_ager', 0.6499968767166138), ('son', 0.6337763071060181), ('kid', 0.6322844624519348), ('youngster', 0.6183817386627197), ('stepfather', 0.5989422798156738)]
#
#
#  radio-> [('radio_stations', 0.7330181002616882), ('Radio', 0.7293578386306763), ('FM_radio', 0.6507299542427063), ('radio_broadcasts', 0.6375086307525635), ('radion', 0.6369773149490356), ('FM', 0.629950761795044), ('station_Fan###', 0.6287457942962646), ('station_CFRB', 0.6274266242980957), ('broadcasting', 0.6133295893669128), ('KMBZ', 0.6132659912109375)]
#
#
#  retro-> [('Retro', 0.724419355392456), ('funky', 0.6827880144119263), ('groovy', 0.6788516640663147), ('retro_chic', 0.6642105579376221), ('retro_styled', 0.6388338804244995), ('retro_kitsch', 0.6342383623123169), ('retro_styling', 0.6315407752990723), ('kitschy', 0.626747190952301), ('retro_vibe', 0.620373010635376), ('nostalgic', 0.613186240196228)]

# %%
for i in range(0,len(Songs)):
    paras = Songs.iloc[i]["text"].split("\n \n")
    for para in paras:
        rake = Rake()
        kyws = rake.extract_keywords_from_text(para)
        for kyw in kyws:
# Out:
#   File "<ipython-input-40-c46d8d7284a2>", line 8
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
len(Songs)
# Out:
# 57650

# %%
Songs.iloc[50]["text"].split("\n  \n")[5]
# Out:
# "Don't go wasting your emotion  \nLay all your love on me  \nDon't go sharing your devotion  \nLay all your love on me\n\n"
