# %%
# Display
from IPython.display import Image, display
img1 = Image('https://cdn.pixabay.com/photo/2017/11/10/12/53/face-2936245_1280.jpg',height=400,width=400,embed=True)
img2 = Image('https://cdn.pixabay.com/photo/2016/10/17/18/06/axe-1748305_1280.jpg',height=400,width=400,embed=True)
im3 = np.array([img1,img2])

# %%
import numpy as np
a1 = np.array(img1)
a2 = np.array(img2)
a3 = np.append(a1,a2)

# %%
from PIL import Image

def merge_images(img1, img2):
    (width1, height1) = img1.width, img1.height
    (width2, height2) = img2.width, img2.height

    result_width = width1 + width2
    result_height = max(height1, height2)

    result = Image.new('RGB', (result_width, result_height))
    result.paste(img1, box=(0, 0,result_width,result_height))
    result.paste(img2, box=(width1, 0, result_width, result_height))
    return result

# %%
from PIL import Image
import numpy as np
a = Image.new(mode='RGB',size=(1000,500))
a.load()
type(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-24abb7b1b9f2> in <module>()
#       2 import numpy as np
#       3 a = Image.new(mode='RGB',size=(1000,500))
# ----> 4 a.load(img1)
#       5 type(a)
#
# TypeError: load() takes 1 positional argument but 2 were given
