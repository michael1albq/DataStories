# %%
# Display
from IPython.display import Image, display
img1 = Image('https://cdn.pixabay.com/photo/2017/11/10/12/53/face-2936245_1280.jpg',height=400,width=400,embed=True)
img2 = Image('https://cdn.pixabay.com/photo/2016/10/17/18/06/axe-1748305_1280.jpg',height=400,width=400,embed=True)
im3 = [img1,img2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-1f2549088c72> in <module>()
#       3 img1 = Image('https://cdn.pixabay.com/photo/2017/11/10/12/53/face-2936245_1280.jpg',height=400,width=400,embed=True)
#       4 img2 = Image('https://cdn.pixabay.com/photo/2016/10/17/18/06/axe-1748305_1280.jpg',height=400,width=400,embed=True)
# ----> 5 im3 = img1 + img2
#
# TypeError: unsupported operand type(s) for +: 'Image' and 'Image'

# %%
display(img1,img2)

# %%
import cv2
import numpy as np
img3 = np.hstack((img1,img2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-e0b9353dd355> in <module>()
#       2 import numpy as np
#       3 img3 = np.hstack((img1,img2))
# ----> 4 cv2.imwrite('Bird3.jpg',img3)
#
# TypeError: img data type = 17 is not supported

# %%
for img in img3.view():
    display(img)
